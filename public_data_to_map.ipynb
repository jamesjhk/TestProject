# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
plt.rc('font', family=font_name)

# %%
df = pd.read_excel('울산광역시 착한가격업소 현황.xlsx')
df
# Out:
#         시도  시군     업종      업소명           연락처             주소 배달여부  주차여부  \
# 0    울산광역시  중구   이미용업     정헤어샵  052-243-7950    당산4길31(우정동)     N    N
# 1    울산광역시  중구  한식_육류  만수원숯불갈비  052-297-4327  해오름 16길2(남외동)     N    Y
# 2    울산광역시  중구   이미용업    하나미용실  052-244-4560    당산길 10(우정동)     N    N
# 3    울산광역시  중구  한식_일반     미락식당  052-294-9933     단장2길2(복산동)     N    N
# 4    울산광역시  중구  한식_일반      수다라  052-293-8818     서원1길3(반구동)     N    N
# ..     ...  ..    ...      ...           ...            ...   ...  ...
# 104  울산광역시  남구  한식_일반    맛고을식당  052-261-1649      돋질로47번길 9     N    N
# 105  울산광역시  남구  한식_일반   춘천돼지국밥  052-266-6645    중앙로166번길 39     N    N
# 106  울산광역시  남구   이미용업      신생원  052-273-5796     문수로445번길 7     Y    Y
# 107  울산광역시  남구  한식_육류   제주숯불갈비  052-266-9297      수암로 177-6     N    N
# 108  울산광역시  남구  한식_육류      다우촌  052-265-7794    두왕로260번길 17     N    N
#
#         메뉴1    가격1      메뉴2      가격2        메뉴3      가격3       메뉴4     가격4  \
# 0         컷트  8000       파마  20000.0         염색  20000.0       NaN     NaN
# 1        쌈정식  7000      삼겹살   8000.0       돼지갈비   8000.0       NaN     NaN
# 2         컷트  7000       파마  20000.0        NaN      NaN       NaN     NaN
# 3         정식  6000    열무비빔밥   6000.0        청국장   6000.0      두루치기  7000.0
# 4        칼국수  5000      비빔밥   6000.0        콩국수   6000.0       냉국수  5000.0
# ..       ...   ...      ...      ...        ...      ...       ...     ...
# 104  된장+김치찌개  7000       정식   7000.0      새알미역국   7000.0       NaN     NaN
# 105     돼지국밥  6000     순대국밥   6000.0       된장찌개   6000.0     콩나물국밥  6000.0
# 106  학생할인짜장면  3500  학생할인 짬뽕   4000.0   학생할인 간짜장   4000.0  학생할인 볶음밥  4000.0
# 107      삼겹살  8000     두루치기   7000.0         정식   6000.0       NaN     NaN
# 108     생삼겹살  6000    양념왕갈비   6000.0  생목살(100g)   6000.0       항정살  6000.0
#
#             위도          경도
# 0    35.553827  129.311302
# 1    35.560785  129.342752
# 2    35.568791  129.332135
# 3    35.568715  129.332905
# 4    35.563260  129.335307
# ..         ...         ...
# 104  35.538521  129.310715
# 105  35.537092  129.317831
# 106  35.533950  129.301957
# 107  35.527013  129.327189
# 108  35.526215  129.312647
#
# [109 rows x 18 columns]

# %%
df = df.filter(['시군','업종','업소명','연락처','주소','위도', '경도'])
df
# Out:
#      시군     업종      업소명           연락처             주소         위도          경도
# 0    중구   이미용업     정헤어샵  052-243-7950    당산4길31(우정동)  35.553827  129.311302
# 1    중구  한식_육류  만수원숯불갈비  052-297-4327  해오름 16길2(남외동)  35.560785  129.342752
# 2    중구   이미용업    하나미용실  052-244-4560    당산길 10(우정동)  35.568791  129.332135
# 3    중구  한식_일반     미락식당  052-294-9933     단장2길2(복산동)  35.568715  129.332905
# 4    중구  한식_일반      수다라  052-293-8818     서원1길3(반구동)  35.563260  129.335307
# ..   ..    ...      ...           ...            ...        ...         ...
# 104  남구  한식_일반    맛고을식당  052-261-1649      돋질로47번길 9  35.538521  129.310715
# 105  남구  한식_일반   춘천돼지국밥  052-266-6645    중앙로166번길 39  35.537092  129.317831
# 106  남구   이미용업      신생원  052-273-5796     문수로445번길 7  35.533950  129.301957
# 107  남구  한식_육류   제주숯불갈비  052-266-9297      수암로 177-6  35.527013  129.327189
# 108  남구  한식_육류      다우촌  052-265-7794    두왕로260번길 17  35.526215  129.312647
#
# [109 rows x 7 columns]

# %% [markdown]
# # The default tiles are set to OpenStreetMap, but Stamen Terrain, Stamen Toner, Mapbox Bright, stamenwatercolor, cartodbpositron, cartodbdark_matter and Mapbox Control Room, and many others tiles are built in.

# %%
map_ulsan = folium.Map(location=[35.542817, 129.323622], zoom_start=12, tiles='OpenStreetMap')
map_ulsan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### icon
#   'home' , 'star' , 'flag' , 'glass' , 'bookmark' , 'bell' , 'info-sign' , 'cloud' , etc
# ### color
#  'beige', 'black', 'blue', 'cadetblue', 'darkblue', 'darkgreen', 'darkpurple', 'darkred', 'gray', 'green', 'lightblue', 'lightgray', 'lightgreen', 'lightred', 'orange', 'pink', 'purple', 'red', 'white'

# %%
marker = folium.Marker([35.5396224,129.3093389], popup='울산광역시청', tooltip='환영합니다', icon=folium.Icon(icon='home', color='black'))
marker.add_to(map_ulsan)
map_ulsan.save('울산_착한가격업소_현황.html')
map_ulsan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
contents = folium.Popup('울산광역시청', max_width=300)
marker = folium.Marker([35.5396224,129.3093389], popup=contents, tooltip='환영합니다', icon=folium.Icon(icon='home', color='red'))
marker.add_to(map_ulsan)
map_ulsan.save('울산_착한가격업소_현황.html')
map_ulsan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in df.index:
    lat = df.loc[i, '위도']
    lng = df.loc[i, '경도']
    contents = folium.Popup('<b>'+df.loc[i, '업소명']+'</b>'+'<br>'+df.loc[i, '주소']+'<br>'+str(df.loc[i, '연락처']), max_width=300)
    marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='home', color='purple'))
    marker.add_to(map_ulsan)

map_ulsan.save('울산_착한가격업소_현황.html')
map_ulsan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
type = df['업종'].value_counts().sort_values(ascending=False)
type
# Out:
# 한식_일반    50
# 이미용업     26
# 한식_육류    13
# 중식        9
# 세탁업       5
# 목욕업       2
# 한식_면류     2
# 카페        1
# 제빵제과      1
# Name: 업종, dtype: int64

# %%
for i in df.index:
    lat = df.loc[i, '위도']
    lng = df.loc[i, '경도']
    contents = folium.Popup('<b>'+df.loc[i, '업소명']+'</b>'+'<br>'+df.loc[i, '주소']+'<br>'+str(df.loc[i, '연락처']), max_width=300)
    
    mark_type =df.loc[i, '업종']
    
    if mark_type == '한식_일반':
        marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='home', color='purple'))
    elif mark_type == '이미용업':
        marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='glass', color='orange'))
    elif mark_type == '한식_육류':
        marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='star', color='red'))
    elif mark_type == '중식':
        marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='flag', color='green'))
    elif mark_type == '세탁업':
        marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='bell', color='black'))
    else :
        marker = folium.Marker([lat, lng], popup=contents, icon=folium.Icon(icon='bookmark', color='blue'))

    marker.add_to(map_ulsan)

map_ulsan.save('울산_착한가격업소_현황.html')
map_ulsan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ‘red’, ‘blue’, ‘green’, ‘purple’, ‘orange’, ‘darkred’, ’lightred’, ‘beige’, ‘darkblue’, ‘darkgreen’, ‘cadetblue’, ‘darkpurple’, ‘white’, ‘pink’, ‘lightblue’, ‘lightgreen’, ‘gray’, ‘black’, ‘lightgray’

# %%
folium.CircleMarker([35.522062,129.2403183], radius=100, color='darkred', fill_color='green', popup='울주군').add_to(map_ulsan)
folium.CircleMarker([35.5438157,129.3278901], radius=50, color='darkblue', fill_color='cadetblue', popup='남구').add_to(map_ulsan)
map_ulsan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
